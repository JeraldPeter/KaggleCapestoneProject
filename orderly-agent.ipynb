# %%
### Enviroment Setup
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Setup and authentication complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Setup and authentication complete.

# %%
import logging
import os

# Clean up any previous logs
for log_file in ["logger.log", "web.log", "tunnel.log"]:
    if os.path.exists(log_file):
        os.remove(log_file)
        print(f"🧹 Cleaned up {log_file}")

# Configure logging with DEBUG log level.
logging.basicConfig(
    filename="logger.log",
    level=logging.DEBUG,
    format="%(filename)s:%(lineno)s %(levelname)s:%(message)s",
)

print("✅ Logging configured")
# Out:
# ✅ Logging configured

# %%
from IPython.core.display import display, HTML
from jupyter_server.serverapp import list_running_servers


# Gets the proxied URL in the Kaggle Notebooks environment
def get_adk_proxy_url():
    PROXY_HOST = "https://kkb-production.jupyter-proxy.kaggle.net"
    ADK_PORT = "8000"

    servers = list(list_running_servers())
    if not servers:
        raise Exception("No running Jupyter servers found.")

    baseURL = servers[0]["base_url"]

    try:
        path_parts = baseURL.split("/")
        kernel = path_parts[2]
        token = path_parts[3]
    except IndexError:
        raise Exception(f"Could not parse kernel/token from base URL: {baseURL}")

    url_prefix = f"/k/{kernel}/{token}/proxy/proxy/{ADK_PORT}"
    url = f"{PROXY_HOST}{url_prefix}"

    styled_html = f"""
    <div style="padding: 15px; border: 2px solid #f0ad4e; border-radius: 8px; background-color: #fef9f0; margin: 20px 0;">
        <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
            <strong>⚠️ IMPORTANT: Action Required</strong>
        </div>
        <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
            The ADK web UI is <strong>not running yet</strong>. You must start it in the next cell.
            <ol style="margin-top: 10px; padding-left: 20px;">
                <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
                <li style="margin-bottom: 5px;">Wait for that cell to show it is "Running" (it will not "complete").</li>
                <li>Once it's running, <strong>return to this button</strong> and click it to open the UI.</li>
            </ol>
            <em style="font-size: 0.9em; color: #555;">(If you click the button before running the next cell, you will get a 500 error.)</em>
        </div>
        <a href='{url}' target='_blank' style="
            display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
            text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
            box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
            Open ADK Web UI (after running cell below) ↗
        </a>
    </div>
    """

    display(HTML(styled_html))

    return url_prefix


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %%
# !adk create orderly-agent --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY
# Out:
# Agent created in /kaggle/working/orderly-agent:
# - .env
# - __init__.py
# - agent.py

# %%
# %%writefile orderly-agent/agent.py

import json
from typing import Dict, Any, List

# Assuming ADK imports are structured like this for the latest version
from google.adk.agents import LlmAgent
from google.adk.tools.function_tool import FunctionTool
from google.adk.models.google_llm import Gemini
from google.genai import types
from typing import Dict, Any, List

# Session & Memory Information

from google.adk.sessions import InMemorySessionService, Session
from google.adk.memory import InMemoryMemoryService 

# --- 1. Mock Tool Implementations ---
# In a real environment, these tools would interface with the MCP (Mission Control Platform)
# or custom external APIs (e.g., databases, microservices).

def mcp_order_management_tool(order_id: str) -> str:
    """
    Retrieves the current status and details for a given order ID from the MCP system.
    Returns a JSON string containing the order status, shipment date, and items.
    """
    # Mock data simulation
    if order_id == "ORD1001":
        return json.dumps({
            "order_id": order_id,
            "status": "In Transit",
            "shipment_date": "2024-11-25",
            "estimated_delivery": "2024-11-28",
            "items": ["Galaxy S24", "Wireless Charger"],
            "tracking_number": "TRK123456"
        })
    elif order_id == "ORD1002":
        return json.dumps({
            "order_id": order_id,
            "status": "Pending Resolution",
            "issue": "Payment validation failed",
            "action_required": "Customer needs to update payment information."
        })
    else:
        return json.dumps({"order_id": order_id, "status": "Not Found", "message": "Order ID is invalid or not recognized."})

# --- 2. Specialist Agents Definition (LlmAgent) ---

order_status_agent = LlmAgent(
    name='order_status_agent',
    model='gemini-2.5-flash-lite',
    description='Creates the specialist agent responsible for handling order status queries.',
    instruction='You are the Order Status Specialist. Your primary goal is to use the mcp_order_management_tool to fetch the requested order details and present the information clearly to the customer. Do not invent information. If an order is In Transit, provide the tracking number and estimated delivery.',
    tools=[mcp_order_management_tool],
    output_key='create_order_status_agent_findings',  # The result of this agent will be stored in the session state with this key.
)

print("✅ Created Order Status Agent.")

issue_resolution_agent=LlmAgent(
        name="issue_resolution_agent",
        instruction = (
        "You are the Issue Resolution Specialist. Your task is to analyze the customer's problem "
        "and provide policy-compliant solutions. If the order status is 'Pending Resolution', "
        "use the 'mcp_order_management_tool' to understand the root cause and advise the customer "
        "on the next steps required to resolve the issue."
        ),
        model='gemini-2.5-flash-lite',
        tools=[mcp_order_management_tool],
        output_key='issue_resolution_agent_findings', 
)

print("✅ Create issue resolution agent.")

# --- 3. Main Router Agent Orchestration (LlmAgent) ---
root_agent=LlmAgent(
    instruction = 'You are the Enterprise Order Management Router Agent. Your sole responsibility is to classify the users intent and route the query to the most appropriate specialist agent provided in your tools list. If the user asks for order status or tracking, route to order_status_agent. If the user expresses a complaint, wants to cancel, or needs help fixing an issue, route to issue_resolution_agent. For general, non-order related questions, answer directly and concisely.',
    name='router_agent',
    model="gemini-2.0-flash",
    sub_agents=[order_status_agent, issue_resolution_agent],
    output_key="root_agent_findings",
)
print("✅ Router Agent Created..")
# Out:
# Overwriting orderly-agent/agent.py

# %%
url_prefix = get_adk_proxy_url()
# Out:
#     <div style="padding: 15px; border: 2px solid #f0ad4e; border-radius: 8px; background-color: #fef9f0; margin: 20px 0;">
#         <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
#             <strong>⚠️ IMPORTANT: Action Required</strong>
#         </div>
#         <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
#             The ADK web UI is <strong>not running yet</strong>. You must start it in the next cell.
#             <ol style="margin-top: 10px; padding-left: 20px;">
#                 <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
#                 <li style="margin-bottom: 5px;">Wait for that cell to show it is "Running" (it will not "complete").</li>
#                 <li>Once it's running, <strong>return to this button</strong> and click it to open the UI.</li>
#             </ol>
#             <em style="font-size: 0.9em; color: #555;">(If you click the button before running the next cell, you will get a 500 error.)</em>
#         </div>
#         <a href='https://kkb-production.jupyter-proxy.kaggle.net/k/280524184/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2IiwidHlwIjoiSldUIn0..OtGnWr-H83x0pnVtp7dWZg.Ifct_Dcau-HzY8e0AUm4kMMUIPEXNt80TpyG-hKrdu8ZfeKiYGFsWlLkrB5R-Ya5RKQTLLUJCEfOoY8_tPFCSMQFhZ0bA-jSi55ZT4ogcgkWc8N7TsW4HAfUD9HfhjclqAkh31lZtrRO6nZ8Ju288_gEV9Ar6gcXIPzN5YwGUdkgjWAxIDBrDic-722aHbxlTIM9eS--nnP-lt05fim102NAnR3AXKooTKi1cIy14KKiltsU9Sk2qSvzo7klXRXT.vOfXTmpHKXtITvGJYusooQ/proxy/proxy/8000' target='_blank' style="
#             display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
#             text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
#             box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
#             Open ADK Web UI (after running cell below) ↗
#         </a>
#     </div>

# %%
# !adk web --log_level DEBUG --url_prefix {url_prefix}
# Out:
# /usr/local/lib/python3.11/dist-packages/google/adk/cli/fast_api.py:130: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   credential_service = InMemoryCredentialService()
# /usr/local/lib/python3.11/dist-packages/google/adk/auth/credential_service/in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# INFO:     Started server process [130]
# INFO:     Waiting for application startup.
#
# +-----------------------------------------------------------------------------+
# | ADK Web Server started                                                      |
# |                                                                             |
# | For local testing, access at http://127.0.0.1:8000.                         |
# +-----------------------------------------------------------------------------+
#
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     35.191.59.113:0 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     35.191.59.115:0 - "GET /dev-ui/ HTTP/1.1" 200 OK
# INFO:     35.191.59.114:0 - "GET /dev-ui/chunk-2WH2EVR6.js HTTP/1.1" 200 OK
# INFO:     35.191.59.113:0 - "GET /dev-ui/main-OS2OH2S3.js HTTP/1.1" 200 OK
# INFO:     35.191.59.115:0 - "GET /dev-ui/styles-EVMPSV3U.css HTTP/1.1" 200 OK
# INFO:     35.191.59.112:0 - "GET /dev-ui/polyfills-B6TNHZQ6.js HTTP/1.1" 200 OK
# INFO:     35.191.59.112:0 - "GET /dev-ui/assets/config/runtime-config.json HTTP/1.1" 200 OK
# INFO:     35.191.59.115:0 - "GET /dev-ui/adk_favicon.svg HTTP/1.1" 200 OK
# INFO:     35.191.59.112:0 - "GET /list-apps?relative_path=./ HTTP/1.1" 200 OK
# INFO:     35.191.59.115:0 - "GET /dev-ui/assets/ADK-512-color.svg HTTP/1.1" 200 OK
# INFO:     35.191.59.113:0 - "GET /builder/app/orderly-agent?ts=1763706288680 HTTP/1.1" 200 OK
# INFO:google_adk.google.adk.cli.adk_web_server:New session created: 3d0cfa1e-cd48-469d-a932-93118fa2e1e2
# INFO:     35.191.59.114:0 - "POST /apps/orderly-agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     35.191.59.115:0 - "GET /apps/orderly-agent/eval_sets HTTP/1.1" 200 OK
# INFO:     35.191.59.114:0 - "GET /apps/orderly-agent/eval_results HTTP/1.1" 200 OK
# INFO:     35.191.59.115:0 - "GET /apps/orderly-agent/users/user/sessions/3d0cfa1e-cd48-469d-a932-93118fa2e1e2 HTTP/1.1" 200 OK
# INFO:     35.191.59.112:0 - "GET /apps/orderly-agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     35.191.59.113:0 - "GET /apps/orderly-agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     35.191.59.114:0 - "GET /debug/trace/session/3d0cfa1e-cd48-469d-a932-93118fa2e1e2 HTTP/1.1" 200 OK
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'appName' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'appName' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'appName' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'userId' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'userId' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'userId' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'sessionId' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'sessionId' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'sessionId' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'newMessage' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'newMessage' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'newMessage' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'streaming' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'streaming' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'streaming' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'stateDelta' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'stateDelta' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'stateDelta' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'invocationId' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'invocationId' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'invocationId' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# INFO:     35.191.71.29:0 - "POST /run_sse HTTP/1.1" 200 OK
# DEBUG:google_adk.google.adk.cli.utils.agent_loader:Loading agent orderly-agent - not in cache.
# DEBUG:google_adk.google.adk.cli.utils.agent_loader:Loading .env for agent orderly-agent from /kaggle/working
# ✅ Created Order Status Agent.
# ✅ Create issue resolution agent.
# ✅ Router Agent Created..
# DEBUG:google_adk.google.adk.cli.utils.agent_loader:Module orderly-agent has no root_agent. Trying next pattern.
# INFO:google_adk.google.adk.cli.utils.agent_loader:Found root_agent in orderly-agent.agent
# INFO:google_adk.google.adk.models.google_llm:Sending out request, model: gemini-2.0-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# DEBUG:google_adk.google.adk.models.google_llm:
# LLM Request:
# -----------------------------------------------------------
# System Instruction:
# You are the Enterprise Order Management Router Agent. Your sole responsibility is to classify the users intent and route the query to the most appropriate specialist agent provided in your tools list. If the user asks for order status or tracking, route to order_status_agent. If the user expresses a complaint, wants to cancel, or needs help fixing an issue, route to issue_resolution_agent. For general, non-order related questions, answer directly and concisely.
#
# You are an agent. Your internal name is "router_agent".
#
#
# You have a list of other agents to transfer to:
#
#
# Agent name: order_status_agent
# Agent description: Creates the specialist agent responsible for handling order status queries.
#
#
# Agent name: issue_resolution_agent
# Agent description:
#
#
# If you are the best to answer the question according to your description, you
# can answer it.
#
# If another agent is better for answering the question according to its
# description, call `transfer_to_agent` function to transfer the
# question to that agent. When transferring, do not generate any text other than
# the function call.
#
# **NOTE**: the only available agents for `transfer_to_agent` function are `issue_resolution_agent`, `order_status_agent`.
#
# -----------------------------------------------------------
# Config:
# {'tools': [{}]}
# -----------------------------------------------------------
# Contents:
# {"parts":[{"text":"Hi "}],"role":"user"}
# -----------------------------------------------------------
# Functions:
# transfer_to_agent: {'agent_name': {'type': <Type.STRING: 'STRING'>}}
# -----------------------------------------------------------
#
# INFO:google_adk.google.adk.models.google_llm:Response received from the model.
# DEBUG:google_adk.google.adk.models.google_llm:
# LLM Response:
# -----------------------------------------------------------
# Text:
# Hi there! How can I help you today?
#
# -----------------------------------------------------------
# Function calls:
#
# -----------------------------------------------------------
# Raw response:
# {"sdk_http_response":{"headers":{"Content-Type":"application/json; charset=UTF-8","Vary":"Origin, X-Origin, Referer","Content-Encoding":"gzip","Date":"Fri, 21 Nov 2025 06:25:45 GMT","Server":"scaffolding on HTTPServer2","X-XSS-Protection":"0","X-Frame-Options":"SAMEORIGIN","X-Content-Type-Options":"nosniff","Server-Timing":"gfet4t7; dur=426","Transfer-Encoding":"chunked"}},"candidates":[{"content":{"parts":[{"text":"Hi there! How can I help you today?\n"}],"role":"model"},"finish_reason":"STOP","avg_logprobs":-0.009676008061929182}],"model_version":"gemini-2.0-flash","response_id":"6QUgaZvYC4yckdUPvvq-sAk","usage_metadata":{"candidates_token_count":11,"candidates_tokens_details":[{"modality":"TEXT","token_count":11}],"prompt_token_count":335,"prompt_tokens_details":[{"modality":"TEXT","token_count":335}],"total_token_count":346}}
# -----------------------------------------------------------
#
# DEBUG:google_adk.google.adk.cli.adk_web_server:Generated event in agent run streaming: {"modelVersion":"gemini-2.0-flash","content":{"parts":[{"text":"Hi there! How can I help you today?\n"}],"role":"model"},"finishReason":"STOP","usageMetadata":{"candidatesTokenCount":11,"candidatesTokensDetails":[{"modality":"TEXT","tokenCount":11}],"promptTokenCount":335,"promptTokensDetails":[{"modality":"TEXT","tokenCount":335}],"totalTokenCount":346},"avgLogprobs":-0.009676008061929182,"invocationId":"e-ceeabcf6-3795-46e0-888b-f0eb1bce7eb1","author":"router_agent","actions":{"stateDelta":{"root_agent_findings":"Hi there! How can I help you today?\n"},"artifactDelta":{},"requestedAuthConfigs":{},"requestedToolConfirmations":{}},"id":"ae8b75bb-6cb8-4a27-9a96-f324497c355e","timestamp":1763706344.625425}
# INFO:     35.191.59.101:0 - "GET /apps/orderly-agent/users/user/sessions/3d0cfa1e-cd48-469d-a932-93118fa2e1e2 HTTP/1.1" 200 OK
# INFO:     35.191.59.100:0 - "GET /debug/trace/session/3d0cfa1e-cd48-469d-a932-93118fa2e1e2 HTTP/1.1" 200 OK
# INFO:     35.191.59.103:0 - "GET /debug/trace/session/3d0cfa1e-cd48-469d-a932-93118fa2e1e2 HTTP/1.1" 200 OK
# INFO:     35.191.59.100:0 - "POST /run_sse HTTP/1.1" 200 OK
# INFO:google_adk.google.adk.models.google_llm:Sending out request, model: gemini-2.0-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# DEBUG:google_adk.google.adk.models.google_llm:
# LLM Request:
# -----------------------------------------------------------
# System Instruction:
# You are the Enterprise Order Management Router Agent. Your sole responsibility is to classify the users intent and route the query to the most appropriate specialist agent provided in your tools list. If the user asks for order status or tracking, route to order_status_agent. If the user expresses a complaint, wants to cancel, or needs help fixing an issue, route to issue_resolution_agent. For general, non-order related questions, answer directly and concisely.
#
# You are an agent. Your internal name is "router_agent".
#
#
# You have a list of other agents to transfer to:
#
#
# Agent name: order_status_agent
# Agent description: Creates the specialist agent responsible for handling order status queries.
#
#
# Agent name: issue_resolution_agent
# Agent description:
#
#
# If you are the best to answer the question according to your description, you
# can answer it.
#
# If another agent is better for answering the question according to its
# description, call `transfer_to_agent` function to transfer the
# question to that agent. When transferring, do not generate any text other than
# the function call.
#
# **NOTE**: the only available agents for `transfer_to_agent` function are `issue_resolution_agent`, `order_status_agent`.
#
# -----------------------------------------------------------
# Config:
# {'tools': [{}]}
# -----------------------------------------------------------
# Contents:
# {"parts":[{"text":"Hi "}],"role":"user"}
# {"parts":[{"text":"Hi there! How can I help you today?\n"}],"role":"model"}
# {"parts":[{"text":"What is the status of my order ?"}],"role":"user"}
# -----------------------------------------------------------
# Functions:
# transfer_to_agent: {'agent_name': {'type': <Type.STRING: 'STRING'>}}
# -----------------------------------------------------------
#
# INFO:google_adk.google.adk.models.google_llm:Response received from the model.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# DEBUG:google_adk.google.adk.models.google_llm:
# LLM Response:
# -----------------------------------------------------------
# Text:
# None
# -----------------------------------------------------------
# Function calls:
# name: transfer_to_agent, args: {'agent_name': 'order_status_agent'}
# -----------------------------------------------------------
# Raw response:
# {"sdk_http_response":{"headers":{"Content-Type":"application/json; charset=UTF-8","Vary":"Origin, X-Origin, Referer","Content-Encoding":"gzip","Date":"Fri, 21 Nov 2025 06:25:53 GMT","Server":"scaffolding on HTTPServer2","X-XSS-Protection":"0","X-Frame-Options":"SAMEORIGIN","X-Content-Type-Options":"nosniff","Server-Timing":"gfet4t7; dur=698","Transfer-Encoding":"chunked"}},"candidates":[{"content":{"parts":[{"function_call":{"args":{"agent_name":"order_status_agent"},"name":"transfer_to_agent"}}],"role":"model"},"finish_reason":"STOP","avg_logprobs":-0.010774519581061143}],"model_version":"gemini-2.0-flash","response_id":"8AUgaam3GIqhnsEPhZzZ8AE","usage_metadata":{"candidates_token_count":13,"candidates_tokens_details":[{"modality":"TEXT","token_count":13}],"prompt_token_count":354,"prompt_tokens_details":[{"modality":"TEXT","token_count":354}],"total_token_count":367}}
# -----------------------------------------------------------
#
# DEBUG:google_adk.google.adk.cli.adk_web_server:Generated event in agent run streaming: {"modelVersion":"gemini-2.0-flash","content":{"parts":[{"functionCall":{"id":"adk-99a57947-eab1-426c-8cda-d94d4e8ff347","args":{"agent_name":"order_status_agent"},"name":"transfer_to_agent"}}],"role":"model"},"finishReason":"STOP","usageMetadata":{"candidatesTokenCount":13,"candidatesTokensDetails":[{"modality":"TEXT","tokenCount":13}],"promptTokenCount":354,"promptTokensDetails":[{"modality":"TEXT","tokenCount":354}],"totalTokenCount":367},"avgLogprobs":-0.010774519581061143,"invocationId":"e-50d25876-4701-475c-aed7-b9a7f705ab0b","author":"router_agent","actions":{"stateDelta":{},"artifactDelta":{},"requestedAuthConfigs":{},"requestedToolConfirmations":{}},"longRunningToolIds":[],"id":"f859412e-32f7-4939-80a3-3f91f37ecd78","timestamp":1763706352.111649}
# DEBUG:google_adk.google.adk.cli.adk_web_server:Generated event in agent run streaming: {"content":{"parts":[{"functionResponse":{"id":"adk-99a57947-eab1-426c-8cda-d94d4e8ff347","name":"transfer_to_agent","response":{"result":null}}}],"role":"user"},"invocationId":"e-50d25876-4701-475c-aed7-b9a7f705ab0b","author":"router_agent","actions":{"stateDelta":{},"artifactDelta":{},"transferToAgent":"order_status_agent","requestedAuthConfigs":{},"requestedToolConfirmations":{}},"id":"39f14de2-1cf9-41fe-807f-083a53e67941","timestamp":1763706353.022313}
# INFO:google_adk.google.adk.models.google_llm:Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# DEBUG:google_adk.google.adk.models.google_llm:
# LLM Request:
# -----------------------------------------------------------
# System Instruction:
# You are the Order Status Specialist. Your primary goal is to use the mcp_order_management_tool to fetch the requested order details and present the information clearly to the customer. Do not invent information. If an order is In Transit, provide the tracking number and estimated delivery.
#
# You are an agent. Your internal name is "order_status_agent". The description about you is "Creates the specialist agent responsible for handling order status queries.".
#
#
# You have a list of other agents to transfer to:
#
#
# Agent name: router_agent
# Agent description:
#
#
# Agent name: issue_resolution_agent
# Agent description:
#
#
# If you are the best to answer the question according to your description, you
# can answer it.
#
# If another agent is better for answering the question according to its
# description, call `transfer_to_agent` function to transfer the
# question to that agent. When transferring, do not generate any text other than
# the function call.
#
# **NOTE**: the only available agents for `transfer_to_agent` function are `issue_resolution_agent`, `router_agent`.
#
# If neither you nor the other agents are best for the question, transfer to your parent agent router_agent.
#
# -----------------------------------------------------------
# Config:
# {'tools': [{}]}
# -----------------------------------------------------------
# Contents:
# {"parts":[{"text":"Hi "}],"role":"user"}
# {"parts":[{"text":"For context:"},{"text":"[router_agent] said: Hi there! How can I help you today?\n"}],"role":"user"}
# {"parts":[{"text":"What is the status of my order ?"}],"role":"user"}
# {"parts":[{"text":"For context:"},{"text":"[router_agent] called tool `transfer_to_agent` with parameters: {'agent_name': 'order_status_agent'}"}],"role":"user"}
# {"parts":[{"text":"For context:"},{"text":"[router_agent] `transfer_to_agent` tool returned result: {'result': None}"}],"role":"user"}
# -----------------------------------------------------------
# Functions:
# transfer_to_agent: {'agent_name': {'type': <Type.STRING: 'STRING'>}}
# mcp_order_management_tool: {'order_id': {'type': <Type.STRING: 'STRING'>}}
# -----------------------------------------------------------
#
# INFO:google_adk.google.adk.models.google_llm:Response received from the model.
# DEBUG:google_adk.google.adk.models.google_llm:
# LLM Response:
# -----------------------------------------------------------
# Text:
# I can help with that! What is your order ID?
# -----------------------------------------------------------
# Function calls:
#
# -----------------------------------------------------------
# Raw response:
# {"sdk_http_response":{"headers":{"Content-Type":"application/json; charset=UTF-8","Vary":"Origin, X-Origin, Referer","Content-Encoding":"gzip","Date":"Fri, 21 Nov 2025 06:25:53 GMT","Server":"scaffolding on HTTPServer2","X-XSS-Protection":"0","X-Frame-Options":"SAMEORIGIN","X-Content-Type-Options":"nosniff","Server-Timing":"gfet4t7; dur=514","Transfer-Encoding":"chunked"}},"candidates":[{"content":{"parts":[{"text":"I can help with that! What is your order ID?"}],"role":"model"},"finish_reason":"STOP","index":0}],"model_version":"gemini-2.5-flash-lite","response_id":"8QUgac6XKuGqnsEP29vV0Ao","usage_metadata":{"candidates_token_count":12,"prompt_token_count":522,"prompt_tokens_details":[{"modality":"TEXT","token_count":522}],"total_token_count":534}}
# -----------------------------------------------------------
#
# DEBUG:google_adk.google.adk.agents.llm_agent:Skipping output save for agent router_agent: event authored by order_status_agent
# DEBUG:google_adk.google.adk.cli.adk_web_server:Generated event in agent run streaming: {"modelVersion":"gemini-2.5-flash-lite","content":{"parts":[{"text":"I can help with that! What is your order ID?"}],"role":"model"},"finishReason":"STOP","usageMetadata":{"candidatesTokenCount":12,"promptTokenCount":522,"promptTokensDetails":[{"modality":"TEXT","tokenCount":522}],"totalTokenCount":534},"invocationId":"e-50d25876-4701-475c-aed7-b9a7f705ab0b","author":"order_status_agent","actions":{"stateDelta":{"create_order_status_agent_findings":"I can help with that! What is your order ID?"},"artifactDelta":{},"requestedAuthConfigs":{},"requestedToolConfirmations":{}},"id":"840257ea-4b70-4e3a-bbf1-3252a8e80230","timestamp":1763706353.025029}
# INFO:     35.191.59.101:0 - "GET /apps/orderly-agent/users/user/sessions/3d0cfa1e-cd48-469d-a932-93118fa2e1e2 HTTP/1.1" 200 OK
# INFO:     35.191.59.100:0 - "GET /debug/trace/session/3d0cfa1e-cd48-469d-a932-93118fa2e1e2 HTTP/1.1" 200 OK
# INFO:     35.191.59.103:0 - "GET /debug/trace/session/3d0cfa1e-cd48-469d-a932-93118fa2e1e2 HTTP/1.1" 200 OK
# INFO:     35.191.59.103:0 - "POST /run_sse HTTP/1.1" 200 OK
# INFO:google_adk.google.adk.models.google_llm:Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# DEBUG:google_adk.google.adk.models.google_llm:
# LLM Request:
# -----------------------------------------------------------
# System Instruction:
# You are the Order Status Specialist. Your primary goal is to use the mcp_order_management_tool to fetch the requested order details and present the information clearly to the customer. Do not invent information. If an order is In Transit, provide the tracking number and estimated delivery.
#
# You are an agent. Your internal name is "order_status_agent". The description about you is "Creates the specialist agent responsible for handling order status queries.".
#
#
# You have a list of other agents to transfer to:
#
#
# Agent name: router_agent
# Agent description:
#
#
# Agent name: issue_resolution_agent
# Agent description:
#
#
# If you are the best to answer the question according to your description, you
# can answer it.
#
# If another agent is better for answering the question according to its
# description, call `transfer_to_agent` function to transfer the
# question to that agent. When transferring, do not generate any text other than
# the function call.
#
# **NOTE**: the only available agents for `transfer_to_agent` function are `issue_resolution_agent`, `router_agent`.
#
# If neither you nor the other agents are best for the question, transfer to your parent agent router_agent.
#
# -----------------------------------------------------------
# Config:
# {'tools': [{}]}
# -----------------------------------------------------------
# Contents:
# {"parts":[{"text":"Hi "}],"role":"user"}
# {"parts":[{"text":"For context:"},{"text":"[router_agent] said: Hi there! How can I help you today?\n"}],"role":"user"}
# {"parts":[{"text":"What is the status of my order ?"}],"role":"user"}
# {"parts":[{"text":"For context:"},{"text":"[router_agent] called tool `transfer_to_agent` with parameters: {'agent_name': 'order_status_agent'}"}],"role":"user"}
# {"parts":[{"text":"For context:"},{"text":"[router_agent] `transfer_to_agent` tool returned result: {'result': None}"}],"role":"user"}
# {"parts":[{"text":"I can help with that! What is your order ID?"}],"role":"model"}
# {"parts":[{"text":"here is my order id \"ORD1001\""}],"role":"user"}
# -----------------------------------------------------------
# Functions:
# transfer_to_agent: {'agent_name': {'type': <Type.STRING: 'STRING'>}}
# mcp_order_management_tool: {'order_id': {'type': <Type.STRING: 'STRING'>}}
# -----------------------------------------------------------
#
# INFO:google_adk.google.adk.models.google_llm:Response received from the model.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# DEBUG:google_adk.google.adk.models.google_llm:
# LLM Response:
# -----------------------------------------------------------
# Text:
# None
# -----------------------------------------------------------
# Function calls:
# name: mcp_order_management_tool, args: {'order_id': 'ORD1001'}
# -----------------------------------------------------------
# Raw response:
# {"sdk_http_response":{"headers":{"Content-Type":"application/json; charset=UTF-8","Vary":"Origin, X-Origin, Referer","Content-Encoding":"gzip","Date":"Fri, 21 Nov 2025 06:26:15 GMT","Server":"scaffolding on HTTPServer2","X-XSS-Protection":"0","X-Frame-Options":"SAMEORIGIN","X-Content-Type-Options":"nosniff","Server-Timing":"gfet4t7; dur=583","Transfer-Encoding":"chunked"}},"candidates":[{"content":{"parts":[{"function_call":{"args":{"order_id":"ORD1001"},"name":"mcp_order_management_tool"}}],"role":"model"},"finish_reason":"STOP","index":0}],"model_version":"gemini-2.5-flash-lite","response_id":"BgYgaYibPN3j7M8PrrOzEA","usage_metadata":{"candidates_token_count":26,"prompt_token_count":548,"prompt_tokens_details":[{"modality":"TEXT","token_count":548}],"total_token_count":574}}
# -----------------------------------------------------------
#
# DEBUG:google_adk.google.adk.cli.adk_web_server:Generated event in agent run streaming: {"modelVersion":"gemini-2.5-flash-lite","content":{"parts":[{"functionCall":{"id":"adk-ceb602e2-d854-40ea-8ef9-c57de6713e5b","args":{"order_id":"ORD1001"},"name":"mcp_order_management_tool"}}],"role":"model"},"finishReason":"STOP","usageMetadata":{"candidatesTokenCount":26,"promptTokenCount":548,"promptTokensDetails":[{"modality":"TEXT","tokenCount":548}],"totalTokenCount":574},"invocationId":"e-1b781f37-e167-40a2-a657-b2996bff610e","author":"order_status_agent","actions":{"stateDelta":{},"artifactDelta":{},"requestedAuthConfigs":{},"requestedToolConfirmations":{}},"longRunningToolIds":[],"id":"5ce7efcd-dba8-4785-bd71-793ce9eba43b","timestamp":1763706374.3715}
# DEBUG:google_adk.google.adk.cli.adk_web_server:Generated event in agent run streaming: {"content":{"parts":[{"functionResponse":{"id":"adk-ceb602e2-d854-40ea-8ef9-c57de6713e5b","name":"mcp_order_management_tool","response":{"result":"{\"order_id\": \"ORD1001\", \"status\": \"In Transit\", \"shipment_date\": \"2024-11-25\", \"estimated_delivery\": \"2024-11-28\", \"items\": [\"Galaxy S24\", \"Wireless Charger\"], \"tracking_number\": \"TRK123456\"}"}}}],"role":"user"},"invocationId":"e-1b781f37-e167-40a2-a657-b2996bff610e","author":"order_status_agent","actions":{"stateDelta":{},"artifactDelta":{},"requestedAuthConfigs":{},"requestedToolConfirmations":{}},"id":"7cb9eb2a-ea0f-481d-8cb1-13f0354c5a40","timestamp":1763706375.162324}
# INFO:google_adk.google.adk.models.google_llm:Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# DEBUG:google_adk.google.adk.models.google_llm:
# LLM Request:
# -----------------------------------------------------------
# System Instruction:
# You are the Order Status Specialist. Your primary goal is to use the mcp_order_management_tool to fetch the requested order details and present the information clearly to the customer. Do not invent information. If an order is In Transit, provide the tracking number and estimated delivery.
#
# You are an agent. Your internal name is "order_status_agent". The description about you is "Creates the specialist agent responsible for handling order status queries.".
#
#
# You have a list of other agents to transfer to:
#
#
# Agent name: router_agent
# Agent description:
#
#
# Agent name: issue_resolution_agent
# Agent description:
#
#
# If you are the best to answer the question according to your description, you
# can answer it.
#
# If another agent is better for answering the question according to its
# description, call `transfer_to_agent` function to transfer the
# question to that agent. When transferring, do not generate any text other than
# the function call.
#
# **NOTE**: the only available agents for `transfer_to_agent` function are `issue_resolution_agent`, `router_agent`.
#
# If neither you nor the other agents are best for the question, transfer to your parent agent router_agent.
#
# -----------------------------------------------------------
# Config:
# {'tools': [{}]}
# -----------------------------------------------------------
# Contents:
# {"parts":[{"text":"Hi "}],"role":"user"}
# {"parts":[{"text":"For context:"},{"text":"[router_agent] said: Hi there! How can I help you today?\n"}],"role":"user"}
# {"parts":[{"text":"What is the status of my order ?"}],"role":"user"}
# {"parts":[{"text":"For context:"},{"text":"[router_agent] called tool `transfer_to_agent` with parameters: {'agent_name': 'order_status_agent'}"}],"role":"user"}
# {"parts":[{"text":"For context:"},{"text":"[router_agent] `transfer_to_agent` tool returned result: {'result': None}"}],"role":"user"}
# {"parts":[{"text":"I can help with that! What is your order ID?"}],"role":"model"}
# {"parts":[{"text":"here is my order id \"ORD1001\""}],"role":"user"}
# {"parts":[{"function_call":{"args":{"order_id":"ORD1001"},"name":"mcp_order_management_tool"}}],"role":"model"}
# {"parts":[{"function_response":{"name":"mcp_order_management_tool","response":{"result":"{\"order_id\": \"ORD1001\", \"status\": \"In Transit\", \"shipment_date\": \"2024-11-25\", \"estimated_delivery\": \"2024-11-28\", \"items\": [\"Galaxy S24\", \"Wireless Charger\"], \"tracking_number\": \"TRK123456\"}"}}}],"role":"user"}
# -----------------------------------------------------------
# Functions:
# transfer_to_agent: {'agent_name': {'type': <Type.STRING: 'STRING'>}}
# mcp_order_management_tool: {'order_id': {'type': <Type.STRING: 'STRING'>}}
# -----------------------------------------------------------
#
# INFO:google_adk.google.adk.models.google_llm:Response received from the model.
# DEBUG:google_adk.google.adk.models.google_llm:
# LLM Response:
# -----------------------------------------------------------
# Text:
# Your order ORD1001 is currently In Transit. It was shipped on 2024-11-25 and is estimated to be delivered by 2024-11-28. The tracking number for your order is TRK123456.
# -----------------------------------------------------------
# Function calls:
#
# -----------------------------------------------------------
# Raw response:
# {"sdk_http_response":{"headers":{"Content-Type":"application/json; charset=UTF-8","Vary":"Origin, X-Origin, Referer","Content-Encoding":"gzip","Date":"Fri, 21 Nov 2025 06:26:15 GMT","Server":"scaffolding on HTTPServer2","X-XSS-Protection":"0","X-Frame-Options":"SAMEORIGIN","X-Content-Type-Options":"nosniff","Server-Timing":"gfet4t7; dur=531","Transfer-Encoding":"chunked"}},"candidates":[{"content":{"parts":[{"text":"Your order ORD1001 is currently In Transit. It was shipped on 2024-11-25 and is estimated to be delivered by 2024-11-28. The tracking number for your order is TRK123456."}],"role":"model"},"finish_reason":"STOP","index":0}],"model_version":"gemini-2.5-flash-lite","response_id":"BwYgaa3aLJGekdUP6d7bmAw","usage_metadata":{"candidates_token_count":62,"prompt_token_count":678,"prompt_tokens_details":[{"modality":"TEXT","token_count":678}],"total_token_count":740}}
# -----------------------------------------------------------
#
# DEBUG:google_adk.google.adk.cli.adk_web_server:Generated event in agent run streaming: {"modelVersion":"gemini-2.5-flash-lite","content":{"parts":[{"text":"Your order ORD1001 is currently In Transit. It was shipped on 2024-11-25 and is estimated to be delivered by 2024-11-28. The tracking number for your order is TRK123456."}],"role":"model"},"finishReason":"STOP","usageMetadata":{"candidatesTokenCount":62,"promptTokenCount":678,"promptTokensDetails":[{"modality":"TEXT","tokenCount":678}],"totalTokenCount":740},"invocationId":"e-1b781f37-e167-40a2-a657-b2996bff610e","author":"order_status_agent","actions":{"stateDelta":{"create_order_status_agent_findings":"Your order ORD1001 is currently In Transit. It was shipped on 2024-11-25 and is estimated to be delivered by 2024-11-28. The tracking number for your order is TRK123456."},"artifactDelta":{},"requestedAuthConfigs":{},"requestedToolConfirmations":{}},"id":"e36d846e-cda0-40c0-8615-af9f9aaefe9d","timestamp":1763706375.16447}
# INFO:     35.191.59.103:0 - "GET /debug/trace/session/3d0cfa1e-cd48-469d-a932-93118fa2e1e2 HTTP/1.1" 200 OK
# INFO:     35.191.59.101:0 - "GET /apps/orderly-agent/users/user/sessions/3d0cfa1e-cd48-469d-a932-93118fa2e1e2 HTTP/1.1" 200 OK
# INFO:     35.191.59.102:0 - "GET /debug/trace/session/3d0cfa1e-cd48-469d-a932-93118fa2e1e2 HTTP/1.1" 200 OK
# DEBUG:google_adk.google.adk.cli.utils.agent_loader:Returning cached agent for orderly-agent (async)
# INFO:     35.191.59.103:0 - "GET /apps/orderly-agent/users/user/sessions/3d0cfa1e-cd48-469d-a932-93118fa2e1e2/events/e36d846e-cda0-40c0-8615-af9f9aaefe9d/graph HTTP/1.1" 200 OK
# INFO:     35.191.59.100:0 - "GET /debug/trace/e36d846e-cda0-40c0-8615-af9f9aaefe9d HTTP/1.1" 200 OK
# DEBUG:google_adk.google.adk.cli.utils.agent_loader:Returning cached agent for orderly-agent (async)
# INFO:     35.191.59.102:0 - "GET /apps/orderly-agent/users/user/sessions/3d0cfa1e-cd48-469d-a932-93118fa2e1e2/events/7cb9eb2a-ea0f-481d-8cb1-13f0354c5a40/graph HTTP/1.1" 200 OK
# INFO:     35.191.59.101:0 - "GET /debug/trace/7cb9eb2a-ea0f-481d-8cb1-13f0354c5a40 HTTP/1.1" 200 OK
# DEBUG:google_adk.google.adk.cli.utils.agent_loader:Returning cached agent for orderly-agent (async)
# INFO:     35.191.59.100:0 - "GET /apps/orderly-agent/users/user/sessions/3d0cfa1e-cd48-469d-a932-93118fa2e1e2/events/5ce7efcd-dba8-4785-bd71-793ce9eba43b/graph HTTP/1.1" 200 OK
# INFO:     35.191.59.103:0 - "GET /debug/trace/5ce7efcd-dba8-4785-bd71-793ce9eba43b HTTP/1.1" 200 OK
# DEBUG:google_adk.google.adk.cli.utils.agent_loader:Returning cached agent for orderly-agent (async)
# INFO:     35.191.59.103:0 - "GET /apps/orderly-agent/users/user/sessions/3d0cfa1e-cd48-469d-a932-93118fa2e1e2/events/840257ea-4b70-4e3a-bbf1-3252a8e80230/graph HTTP/1.1" 200 OK
# INFO:     35.191.59.102:0 - "GET /debug/trace/840257ea-4b70-4e3a-bbf1-3252a8e80230 HTTP/1.1" 200 OK
# DEBUG:google_adk.google.adk.cli.utils.agent_loader:Returning cached agent for orderly-agent (async)
# INFO:     35.191.59.101:0 - "GET /apps/orderly-agent/users/user/sessions/3d0cfa1e-cd48-469d-a932-93118fa2e1e2/events/39f14de2-1cf9-41fe-807f-083a53e67941/graph HTTP/1.1" 200 OK
# INFO:     35.191.59.100:0 - "GET /debug/trace/39f14de2-1cf9-41fe-807f-083a53e67941 HTTP/1.1" 200 OK
